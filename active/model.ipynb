# %% [markdown]
# # Imports

# %% [markdown]
# ### Make sure this notebook is in the "leam_us/active" directory.

# %%
import torch
from model.pytorch.dcrnn_supervisor import DCRNNSupervisor
from lib.utils import load_graph_data
import yaml
import numpy as np

# %% [markdown]
# ### Model's weights path. Ensure all files I sent are in a path as listed below. There are other functions that have dependencies on this type of folder structure.

# %%
model_folder_path = "seed1/itr11"

# %% [markdown]
# ### Configuration pathway

# %%
config_path = "data/model/dcrnn_cov.yaml"

# %% [markdown]
# ### Model tar file pathway

# %%
model_tar = torch.load(f"{model_folder_path}/model_epo101.tar")

# %% [markdown]
# ### Loading the configuration file and the adjacency matrix

# %%
with open(config_path) as f:
        supervisor_config = yaml.safe_load(f)

        graph_pkl_filename = supervisor_config['data'].get('graph_pkl_filename')
        sensor_ids, sensor_id_to_ind, adj_mx = load_graph_data(graph_pkl_filename)

# %% [markdown]
# ### Necessary Arguments for creating a DCRNNSupervisor model

# %%
random_seed = 1
iteration = 11
max_iter = 12

# %% [markdown]
# ### Model Creatiion

# %%
model = DCRNNSupervisor(random_seed, iteration, max_iter, adj_mx, **model_tar)
# Out:
# 2025-02-07 18:28:45,497 - INFO - Log directory: data/model\dcrnn_DR_1_h_28_16_lr_0.0008_bs_128_0207182845_1_11/
# 2025-02-07 18:29:00,496 - INFO - Model created

# %% [markdown]
# ### This is necessary for the load_model() function to know the model weight locations

# %%
model._epoch_num = 101

# %% [markdown]
# ### Load the model

# %%
model.load_model()
# Out:
# 2025-02-07 18:29:01,685 - INFO - Loaded model at 101

# %% [markdown]
# ### There can be a little experimentation here of the 'dataset' argument

# %%
model.evaluate()
# Out:
# <generator object DataLoader.get_iterator.<locals>._wrapper at 0x000001AE70139AC0>
# Iteration: 0
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 1
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 2
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 3
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 4
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 5
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 6
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 7
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 8
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 9
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 10
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 11
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 12
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 13
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 14
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 15
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# Iteration: 16
# (128, 28, 58, 10)
# (128, 28, 24)
# (128, 24)
# (8227.506,
#  53073.246,
#  {'prediction': array([[[5.4823364e+01, 2.6583040e+01, 2.2328602e+01, ...,
#            6.1966486e+00, 4.6376762e+00, 3.5907903e+00],
#           [4.7840855e+01, 2.3697824e+01, 1.9783297e+01, ...,
#            5.5793242e+00, 4.1731849e+00, 3.2527604e+00],
#           [4.1564312e+01, 2.0729504e+01, 1.7351725e+01, ...,
#            5.1131215e+00, 3.8518243e+00, 3.0763073e+00],
#           ...,
#           [1.1341774e+04, 4.6476455e+03, 3.2132300e+03, ...,
#            2.4439966e+02, 4.6684369e+02, 1.7910605e+02],
#           [1.1376192e+04, 4.6645449e+03, 3.2261362e+03, ...,
#            2.4478119e+02, 4.6762067e+02, 1.7905856e+02],
#           [1.1435600e+04, 4.6859688e+03, 3.2357930e+03, ...,
#            2.4566048e+02, 4.6847903e+02, 1.7984157e+02]],
#
#          [[1.6278187e+03, 5.5069238e+02, 4.2179947e+02, ...,
#            3.6870502e+01, 2.2732197e+01, 1.2844892e+01],
#           [1.6678132e+03, 5.6344183e+02, 4.3047198e+02, ...,
#            3.7706295e+01, 2.2595886e+01, 1.2368067e+01],
#           [1.8231251e+03, 6.1359045e+02, 4.6880490e+02, ...,
#            4.0326931e+01, 2.4192360e+01, 1.3061761e+01],
#            1.79999981e+01, 1.79999981e+01, 2.00000000e+00],
#           [2.32400000e+03, 1.00200006e+03, 6.56000183e+02, ...,
#            1.70000000e+01, 1.40000019e+01, 3.00000000e+00],
#           ...,
#           [7.04800293e+03, 2.95699951e+03, 1.93500012e+03, ...,
#            4.99999962e+01, 4.20000000e+01, 1.10000000e+01],
#           [7.04800293e+03, 2.95699951e+03, 1.93500012e+03, ...,
#            4.99999962e+01, 4.20000000e+01, 1.10000000e+01],
#           [7.04800293e+03, 2.95699951e+03, 1.93500012e+03, ...,
#            4.99999962e+01, 4.20000000e+01, 1.10000000e+01]],
#
#          [[1.97600012e+03, 9.59999939e+02, 5.87999939e+02, ...,
#            7.00000000e+00, 2.20000000e+01, 3.00000000e+00],
#           [2.00800024e+03, 8.83000122e+02, 6.39999939e+02, ...,
#            1.10000000e+01, 1.50000000e+01, 1.00000000e+00],
#           [2.08000049e+03, 9.85999939e+02, 6.23000122e+02, ...,
#            1.10000000e+01, 1.90000019e+01, 2.00000000e+00],
#           ...,
#           [6.65199902e+03, 2.87500000e+03, 1.87400012e+03, ...,
#            6.40000153e+01, 3.90000038e+01, 1.00000010e+01],
#           [6.65199902e+03, 2.87500000e+03, 1.87400012e+03, ...,
#            6.40000153e+01, 3.90000038e+01, 1.00000010e+01],
#           [6.65199902e+03, 2.87500000e+03, 1.87400012e+03, ...,
#            6.40000153e+01, 3.90000038e+01, 1.00000010e+01]],
#
#          [[1.80000037e+03, 9.23000000e+02, 5.47999939e+02, ...,
#            1.10000000e+01, 1.19999990e+01, 2.00000000e+00],
#           [1.85900012e+03, 8.18000061e+02, 5.99000000e+02, ...,
#            9.00000095e+00, 1.19999990e+01, 4.00000048e+00],
#           [1.93699988e+03, 9.06000061e+02, 5.69000000e+02, ...,
#            1.70000000e+01, 8.00000000e+00, 1.00000000e+00],
#           ...,
#           [6.38600146e+03, 2.71399976e+03, 1.85800000e+03, ...,
#            5.09999962e+01, 5.49999924e+01, 5.00000000e+00],
#           [6.38600146e+03, 2.71399976e+03, 1.85800000e+03, ...,
#            5.09999962e+01, 5.49999924e+01, 5.00000000e+00],
#           [6.38600146e+03, 2.71399976e+03, 1.85800000e+03, ...,
#            5.09999962e+01, 5.49999924e+01, 5.00000000e+00]]], dtype=float32)})

# %%
inputer = 256

# %%
x = np.random.randn(inputer, 28, 58, 10)
y = np.random.randn(inputer, 28, 24)
x0 = np.random.randn(inputer, 24)
x, y, x0 = model._prepare_data(x, y, x0)

# %%
with torch.no_grad():
    result = model.dcrnn_model(x, y, x0, 0, True, model.z_mean_all, model.z_var_temp_all)[0].cpu()

result
# Out:
# tensor([[[ 5.4928,  4.8512,  4.6644,  ...,  3.1788,  3.1788,  2.5787],
#          [ 0.8080,  0.5475,  0.5180,  ...,  0.3936,  0.2512,  0.2314],
#          [ 0.7778,  0.4773,  0.4322,  ...,  0.3701,  0.2523,  0.3000],
#          ...,
#          [ 7.6129,  6.8809,  6.6911,  ...,  4.7545,  5.2214,  4.3421],
#          [ 1.1565,  0.9009,  0.8988,  ...,  0.6683,  0.6104,  0.5220],
#          [ 1.8824,  1.4922,  1.3958,  ...,  0.9083,  0.7647,  0.6270]],
#
#         [[12.7179, 11.7588, 11.4001,  ...,  7.7819,  7.5892,  5.7611],
#          [ 1.8296,  1.2124,  1.1228,  ...,  0.7693,  0.3165,  0.2801],
#          [ 2.0524,  1.4918,  1.3115,  ...,  0.8339,  0.4482,  0.4670],
#          ...,
#          [ 9.7846,  8.9621,  8.6387,  ...,  5.8891,  6.5497,  5.2739],
#          [ 3.0380,  2.4118,  2.2666,  ...,  1.3164,  1.0174,  0.8601],
#          [ 2.0563,  1.4891,  1.3094,  ...,  0.7331,  0.3768,  0.4618]],
#
#         [[13.2435, 12.3419, 11.9894,  ...,  8.1667,  7.9192,  5.7653],
#          [ 2.5993,  1.7489,  1.6055,  ...,  1.0620,  0.3971,  0.3506],
#          [ 2.3274,  1.5616,  1.3830,  ...,  0.9100,  0.3502,  0.4805],
#          ...,
#          [ 9.6037,  8.7803,  8.4552,  ...,  5.7526,  6.4494,  5.2294],
#          [ 3.2787,  2.5614,  2.3219,  ...,  1.2741,  0.7349,  0.5822],
#          [ 2.1688,  1.3825,  1.2106,  ...,  0.6896,  0.1728,  0.4189]],
#
#         ...,
#
#         [[ 9.6992,  8.8908,  8.5481,  ...,  5.8132,  6.4766,  5.2476],
#          [ 4.2056,  3.1629,  2.9320,  ...,  2.0796,  1.0952,  0.6691],
#          [ 3.4222,  2.3944,  2.1996,  ...,  1.6939,  0.7909,  0.5732],
#          ...,
#          [ 9.2085,  8.3957,  8.0478,  ...,  5.4981,  6.1836,  5.1091],
#          [ 4.4151,  3.3433,  3.1196,  ...,  2.1828,  1.1328,  0.7100],
#          [ 4.1238,  3.0782,  2.8396,  ...,  1.9499,  1.0066,  0.6311]],
#
#         [[ 9.6738,  8.8644,  8.5230,  ...,  5.8000,  6.4660,  5.2403],
#          [ 4.2028,  3.1631,  2.9327,  ...,  2.0813,  1.0971,  0.6715],
#          [ 3.4474,  2.4191,  2.2230,  ...,  1.7128,  0.8060,  0.5773],
#          ...,
#          [ 9.1979,  8.3819,  8.0358,  ...,  5.4889,  6.1758,  5.1039],
#          [ 4.4152,  3.3448,  3.1207,  ...,  2.1840,  1.1359,  0.7102],
#          [ 4.1404,  3.0940,  2.8579,  ...,  1.9773,  1.0249,  0.6380]],
#
#         [[ 9.6123,  8.8093,  8.4644,  ...,  5.7618,  6.4283,  5.2270],
#          [ 4.2097,  3.1705,  2.9402,  ...,  2.0866,  1.1036,  0.6736],
#          [ 3.4935,  2.4585,  2.2637,  ...,  1.7461,  0.8303,  0.5846],
#          ...,
#          [ 9.2127,  8.3950,  8.0513,  ...,  5.4992,  6.1894,  5.1092],
#          [ 4.4032,  3.3360,  3.1106,  ...,  2.1823,  1.1394,  0.7099],
#          [ 4.1604,  3.1146,  2.8814,  ...,  2.0064,  1.0440,  0.6450]]])

# %%
z_var_all = 0.1 + 0.9 * torch.sigmoid(model.z_var_temp_all)
zs = model.dcrnn_model.sample_z(model.z_mean_all, z_var_all, inputer)
outputs_hidden = model.dcrnn_model.dcrnn_to_hidden(x)
# xz = torch.cat([h_outputs, zs], dim=-1)
output = model.dcrnn_model.decoder(x0, outputs_hidden, zs)
output
# Out:
# tensor([[[ 5.6938,  5.0375,  4.8464,  ...,  3.2998,  3.3240,  2.7109],
#          [ 0.7466,  0.4870,  0.4623,  ...,  0.3540,  0.2142,  0.2286],
#          [ 1.4672,  1.1062,  1.0242,  ...,  0.7036,  0.5476,  0.4714],
#          ...,
#          [ 6.7464,  6.0449,  5.9145,  ...,  4.3286,  4.8096,  4.0535],
#          [ 0.9556,  0.7154,  0.7085,  ...,  0.5491,  0.4899,  0.4118],
#          [ 1.5160,  1.1437,  1.0614,  ...,  0.6953,  0.5923,  0.5277]],
#
#         [[12.7341, 11.8003, 11.4416,  ...,  7.7701,  7.6330,  5.7578],
#          [ 1.6875,  1.0713,  0.9920,  ...,  0.6796,  0.2449,  0.2719],
#          [ 2.4945,  1.9114,  1.6899,  ...,  0.9763,  0.5667,  0.5562],
#          ...,
#          [ 9.6717,  8.8435,  8.5238,  ...,  5.8222,  6.4910,  5.2422],
#          [ 1.8774,  1.3694,  1.2432,  ...,  0.7071,  0.4249,  0.4519],
#          [ 2.0040,  1.4389,  1.2535,  ...,  0.7056,  0.3671,  0.4684]],
#
#         [[12.9775, 12.0838, 11.7292,  ...,  7.9726,  7.8438,  5.7815],
#          [ 2.4178,  1.5635,  1.4260,  ...,  0.9470,  0.3025,  0.3242],
#          [ 2.5149,  1.7554,  1.5447,  ...,  0.9138,  0.3602,  0.5059],
#          ...,
#          [ 9.5708,  8.7463,  8.4213,  ...,  5.7331,  6.4311,  5.2204],
#          [ 2.2629,  1.5296,  1.3710,  ...,  0.7850,  0.2566,  0.3872],
#          [ 2.0941,  1.3113,  1.1403,  ...,  0.6644,  0.1543,  0.4202]],
#
#         ...,
#
#         [[ 9.6457,  8.8373,  8.4955,  ...,  5.7839,  6.4523,  5.2342],
#          [ 4.2264,  3.1834,  2.9524,  ...,  2.0910,  1.1031,  0.6702],
#          [ 3.5236,  2.4888,  2.2960,  ...,  1.7474,  0.8338,  0.5931],
#          ...,
#          [ 9.2019,  8.3897,  8.0413,  ...,  5.4935,  6.1781,  5.1067],
#          [ 3.9888,  2.9327,  2.7279,  ...,  1.9947,  1.0032,  0.6645],
#          [ 3.9486,  2.9009,  2.6714,  ...,  1.8632,  0.9445,  0.6107]],
#
#         [[ 9.6254,  8.8162,  8.4753,  ...,  5.7719,  6.4420,  5.2281],
#          [ 4.2269,  3.1874,  2.9564,  ...,  2.0949,  1.1064,  0.6724],
#          [ 3.5524,  2.5163,  2.3222,  ...,  1.7681,  0.8501,  0.5973],
#          ...,
#          [ 9.1907,  8.3750,  8.0287,  ...,  5.4837,  6.1698,  5.1011],
#          [ 3.9906,  2.9339,  2.7297,  ...,  2.0008,  1.0098,  0.6648],
#          [ 3.9660,  2.9173,  2.6906,  ...,  1.8911,  0.9633,  0.6182]],
#
#         [[ 9.5714,  8.7687,  8.4241,  ...,  5.7376,  6.4074,  5.2166],
#          [ 4.2349,  3.1965,  2.9654,  ...,  2.1004,  1.1126,  0.6748],
#          [ 3.6028,  2.5602,  2.3670,  ...,  1.8041,  0.8762,  0.6051],
#          ...,
#          [ 9.2044,  8.3865,  8.0428,  ...,  5.4933,  6.1837,  5.1062],
#          [ 3.9850,  2.9311,  2.7254,  ...,  2.0007,  1.0138,  0.6649],
#          [ 3.9868,  2.9387,  2.7147,  ...,  1.9205,  0.9829,  0.6257]]],
#        grad_fn=<CatBackward0>)
